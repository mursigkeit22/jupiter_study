# %%
from abc import ABC, abstractmethod

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
class Hero:
    def __init__(self):
        self.positive_effects = []
        self.negative_effects = []
        self.stats = {
            "HP": 128,  # health points
            "MP": 42,  # magic points, 
            "SP": 100,  # skill points
            "Strength": 15,  # сила
            "Perception": 4,  # восприятие
            "Endurance": 8,  # выносливость
            "Charisma": 2,  # харизма
            "Intelligence": 3,  # интеллект
            "Agility": 8,  # ловкость 
            "Luck": 1  # удача
        }

    def get_positive_effects(self):
        return self.positive_effects.copy()

    def get_negative_effects(self):
        return self.negative_effects.copy()

    def get_stats(self):
        return self.stats.copy()

# %% [markdown]
# AbstractEffect,  AbstractPositive,  AbstractNegative, Berserk, Blessing, Weakness, Curse, EvilEye

# %%
class AbstractEffect(ABC, Hero):
    def __init__(self, base):
        self.base = base
        print(f'AbstractEffect, init, self.base: {self.base}')
#         self.positive_effects = self.base.positive_effects
#         self.negative_effects = self.base.negative_effects
#         print(f'AbstractEffect, init, self.positive_effects {self.positive_effects}, self.negative_effects {self.negative_effects}')
#         self.stats = self.base.stats
    
    def get_positive_effects(self):
        print(f'AbstractEffect, get_positive_effects, self.base: {self.base}')
        return self.base.get_positive_effects()

    def get_negative_effects(self):
        print(f'AbstractEffect, get_negative_effects, self.base: {self.base}')
        return self.base.get_negative_effects()  
       
    @abstractmethod
    def get_stats(self):
        pass

# %%
class AbstractNegative(AbstractEffect):
    
    @abstractmethod
    def get_negative_effects(self):
        pass

class AbstractPositive(AbstractEffect):
    
    @abstractmethod
    def get_positive_effects(self):
        pass

# %%
class EvilEye(AbstractNegative):
    
    """уменьшает  характеристику Удача на 10."""
    
    def get_negative_effects(self):
        negative_effects = self.base.get_negative_effects()
        print(f'in EvilEye, negative_effects before appending: {negative_effects}')
        print(f'self.base: {self.base}')
        negative_effects.append('EvilEye')
        return negative_effects
    
    def get_stats(self):
        stats = self.base.get_stats()
        print(f'EvilEye, get_stats, self.base: {self.base}')
        stats['Luck'] -= 10
        return stats
    
class Berserk(AbstractPositive):
    
    """Увеличивает характеристики: Сила, Выносливость, Ловкость, Удача на 7;уменьшает характеристики:
    Восприятие, Харизма, Интеллект на 3; количество единиц здоровья увеличивается на 50."""
    
    def get_positive_effects(self):
        positive_effects = self.base.get_positive_effects()
        print(f'in Berserk, positive_effects before appending: {positive_effects}')
        print(f'self.base: {self.base}')
        positive_effects.append('Berserk')
        return positive_effects
   
    def get_stats(self):
        stats = self.base.get_stats()
        print(f'Berserk, get_stats, self.base: {self.base}')
        stats["HP"] += 50
        stats["Strength"] += 7
        stats["Perception"] -=3
        stats["Endurance"] +=7
        stats["Charisma"] -=3
        stats["Intelligence"] -=3
        stats["Agility"] +=7 
        stats["Luck"] +=7 
        return stats
    
class Curse(AbstractNegative):
    """уменьшает все основные характеристики на 2."""
    
    def get_stats(self):
        stats = self.base.get_stats()
        print(f'Curse, get_stats, self.base: {self.base}')
        stats["Strength"] -= 2
        stats["Perception"] -= 2
        stats["Endurance"] -= 2
        stats["Charisma"] -= 2
        stats["Intelligence"] -= 2
        stats["Agility"] -= 2 
        stats["Luck"] -= 2 
        return stats
    
    def get_negative_effects(self):
        negative_effects = self.base.get_negative_effects()
        print(f'in Curse, negative_effects before appending: {negative_effects}')
        print(f'self.base: {self.base}')
        negative_effects.append('Curse')
        return negative_effects

# %%
hero = Hero()
print(hero)
hero.get_stats()
hero.stats
hero.get_negative_effects()
hero.get_positive_effects()
# Out:
# <__main__.Hero object at 0x0000027BFC1D1908>
# {'HP': 128,
#  'MP': 42,
#  'SP': 100,
#  'Strength': 15,
#  'Perception': 4,
#  'Endurance': 8,
#  'Charisma': 2,
#  'Intelligence': 3,
#  'Agility': 8,
#  'Luck': 1}
# {'HP': 128,
#  'MP': 42,
#  'SP': 100,
#  'Strength': 15,
#  'Perception': 4,
#  'Endurance': 8,
#  'Charisma': 2,
#  'Intelligence': 3,
#  'Agility': 8,
#  'Luck': 1}
# []
# []

# %%
brs1 = Berserk(hero)
print(brs1)
# print(brs1.positive_effects)
print(brs1.base)
print(brs1.base.positive_effects)
# Out:
# AbstractEffect, init, self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# <__main__.Berserk object at 0x0000027BFC1D1F48>
# <__main__.Hero object at 0x0000027BFC1D1908>
# []

# %%
brs1.get_positive_effects()
# print(f'brs1.positive_effects: {brs1.positive_effects}') # AttributeError: 'Berserk' object has no attribute 'positive_effects'
print(f'brs1.base.positive_effects: {brs1.base.positive_effects}')
# Out:
# in Berserk, positive_effects before appending: []
# self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# ['Berserk']
# brs1.base.positive_effects: []

# %%
brs1.get_negative_effects()
# Out:
# AbstractEffect, get_negative_effects, self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# []

# %%
brs1.get_stats()
# {'HP': 178, 'MP': 42, 'SP': 100, 'Strength': 22, 'Perception': 1, 'Endurance': 15,
#  'Charisma': -1, 'Intelligence': 0, 'Agility': 15, 'Luck': 8}
# Out:
# Berserk, get_stats, self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# {'HP': 178,
#  'MP': 42,
#  'SP': 100,
#  'Strength': 22,
#  'Perception': 1,
#  'Endurance': 15,
#  'Charisma': -1,
#  'Intelligence': 0,
#  'Agility': 15,
#  'Luck': 8}

# %%
brs2 = Berserk(brs1)

print(brs2)
# print(brs2.positive_effects)
print(brs2.base)
# print(brs2.base.positive_effects) #AttributeError: 'Berserk' object has no attribute 'positive_effects'
# Out:
# AbstractEffect, init, self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# <__main__.Berserk object at 0x0000027BFC1EDDC8>
# <__main__.Berserk object at 0x0000027BFC1D1F48>

# %%
cur1 = Curse(brs2)
print(cur1)
print(cur1.base)
# Out:
# AbstractEffect, init, self.base: <__main__.Berserk object at 0x0000027BFC1EDDC8>
# <__main__.Curse object at 0x0000027BFC1FB108>
# <__main__.Berserk object at 0x0000027BFC1EDDC8>

# %%
cur1.get_stats()
# {'HP': 228, 'MP': 42, 'SP': 100, 'Strength': 27, 'Perception': -4, 'Endurance': 20, 'Charisma': -6, 
# 'Intelligence': -5, 'Agility': 20, 'Luck': 13}
cur1.get_positive_effects()
# ['Berserk', 'Berserk']
cur1.get_negative_effects()
# ['Curse']
# Out:
# Berserk, get_stats, self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# Berserk, get_stats, self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# Curse, get_stats, self.base: <__main__.Berserk object at 0x0000027BFC1EDDC8>
# {'HP': 228,
#  'MP': 42,
#  'SP': 100,
#  'Strength': 27,
#  'Perception': -4,
#  'Endurance': 20,
#  'Charisma': -6,
#  'Intelligence': -5,
#  'Agility': 20,
#  'Luck': 13}
# AbstractEffect, get_positive_effects, self.base: <__main__.Berserk object at 0x0000027BFC1EDDC8>
# in Berserk, positive_effects before appending: []
# self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# in Berserk, positive_effects before appending: ['Berserk']
# self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# ['Berserk', 'Berserk']
# AbstractEffect, get_negative_effects, self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# AbstractEffect, get_negative_effects, self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# in Curse, negative_effects before appending: []
# self.base: <__main__.Berserk object at 0x0000027BFC1EDDC8>
# ['Curse']

# %%
# снимаем эффект Berserk
cur1.base = brs1
cur1.get_stats()
# {'HP': 178, 'MP': 42, 'SP': 100, 'Strength': 20, 'Perception': -1, 'Endurance': 13, 'Charisma': -3, 
# 'Intelligence': -2, 'Agility': 13, 'Luck': 6}
cur1.get_positive_effects()
# ['Berserk']
cur1.get_negative_effects()
# ['Curse']
# Out:
# Berserk, get_stats, self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# Curse, get_stats, self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# {'HP': 178,
#  'MP': 42,
#  'SP': 100,
#  'Strength': 20,
#  'Perception': -1,
#  'Endurance': 13,
#  'Charisma': -3,
#  'Intelligence': -2,
#  'Agility': 13,
#  'Luck': 6}
# AbstractEffect, get_positive_effects, self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# in Berserk, positive_effects before appending: []
# self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# ['Berserk']
# AbstractEffect, get_negative_effects, self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# in Curse, negative_effects before appending: []
# self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# ['Curse']

# %%
cur2 = Curse(cur1)
# Out:
# AbstractEffect, init, self.base: <__main__.Curse object at 0x0000027BFC1FB108>

# %%
cur2.get_negative_effects()
cur2.get_positive_effects()
cur2.get_stats()
# Out:
# AbstractEffect, get_negative_effects, self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# in Curse, negative_effects before appending: []
# self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# in Curse, negative_effects before appending: ['Curse']
# self.base: <__main__.Curse object at 0x0000027BFC1FB108>
# ['Curse', 'Curse']
# AbstractEffect, get_positive_effects, self.base: <__main__.Curse object at 0x0000027BFC1FB108>
# AbstractEffect, get_positive_effects, self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# in Berserk, positive_effects before appending: []
# self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# ['Berserk']
# Berserk, get_stats, self.base: <__main__.Hero object at 0x0000027BFC1D1908>
# Curse, get_stats, self.base: <__main__.Berserk object at 0x0000027BFC1D1F48>
# Curse, get_stats, self.base: <__main__.Curse object at 0x0000027BFC1FB108>
# {'HP': 178,
#  'MP': 42,
#  'SP': 100,
#  'Strength': 18,
#  'Perception': -3,
#  'Endurance': 11,
#  'Charisma': -5,
#  'Intelligence': -4,
#  'Agility': 11,
#  'Luck': 4}
