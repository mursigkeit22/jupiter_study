# %%
class rec:
    pass
rec.name = 'Bob'
rec.age = 40
x = rec()
y = rec()

# %%
x.name, y.name
# Out:
# ('Bob', 'Bob')

# %%
x.name = 'Sue'
rec.name, x.name, y.name
# Out:
# ('Bob', 'Sue', 'Bob')

# %%
rec.__dict__.keys()
# Out:
# dict_keys(['__module__', '__dict__', '__weakref__', '__doc__', 'name', 'age'])

# %%
list(x.__dict__.keys())
# Out:
# ['name']

# %%
x.__dict__
# Out:
# {'name': 'Sue'}

# %%
y.__dict__.keys()
# Out:
# dict_keys([])

# %%
x.name, x.__dict__['name']
# Out:
# ('Sue', 'Sue')

# %%
x.__dict__['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-4e98118787c4> in <module>
# ----> 1 x.__dict__['age']
#
# KeyError: 'age'

# %%
x.__class__
# Out:
# __main__.rec

# %%
rec.__bases__
# Out:
# (object,)

# %%
def uppername(obj):
    return obj.name.upper()
uppername(x)
# Out:
# 'SUE'

# %%
rec.method = '55'
rec.method
# Out:
# '55'

# %%
rec.method = uppername
x.method()
# Out:
# 'SUE'

# %%
y.method()
# Out:
# 'BOB'

# %%
x.method
# Out:
# <bound method uppername of <__main__.rec object at 0x0000029368014978>>

# %%
rec.method
# Out:
# <function __main__.uppername(obj)>

# %%
rec.method(y)
# Out:
# 'BOB'

# %%
rec.method()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-52500dbf23f9> in <module>
# ----> 1 rec.method()
#
# TypeError: uppername() missing 1 required positional argument: 'obj'

# %%
class Person:
    def __init__(self, name, job = None, pay = 0):
        self.name = name
        self.job = job
        self.pay = pay
