# %%
import json

# %%
filename = "2020_APRIL.json"

with open(filename, encoding='UTF-8') as f:
    myjson = f.read()

loaded_json = json.loads(myjson)

# %%
for el in loaded_json:
    print(el)
# Out:
# timelineObjects

# %%
print(len(loaded_json['timelineObjects']))
# Out:
# 201

# %%
print(loaded_json['timelineObjects'][0])
# Out:
# {'activitySegment': {'startLocation': {'latitudeE7': 557067473, 'longitudeE7': 376767245}, 'endLocation': {'latitudeE7': 557076211, 'longitudeE7': 376743308}, 'duration': {'startTimestampMs': '1585756735302', 'endTimestampMs': '1585757705753'}, 'distance': 936, 'activityType': 'WALKING', 'confidence': 'HIGH', 'activities': [{'activityType': 'WALKING', 'probability': 87.66182065010071}, {'activityType': 'IN_PASSENGER_VEHICLE', 'probability': 6.071301177144051}, {'activityType': 'STILL', 'probability': 4.064884036779404}, {'activityType': 'CYCLING', 'probability': 0.9407142177224159}, {'activityType': 'IN_BUS', 'probability': 0.5061136558651924}, {'activityType': 'RUNNING', 'probability': 0.42595332488417625}, {'activityType': 'MOTORCYCLING', 'probability': 0.09140961919911206}, {'activityType': 'IN_TRAM', 'probability': 0.0813109683804214}, {'activityType': 'IN_SUBWAY', 'probability': 0.06504027987830341}, {'activityType': 'SKIING', 'probability': 0.044811522820964456}, {'activityType
# ...

# %%
print(loaded_json['timelineObjects'][1])
# Out:
# {'placeVisit': {'location': {'latitudeE7': 557072120, 'longitudeE7': 376737380, 'placeId': 'ChIJv0wlC860SkERJrrYg7qPROs', 'address': '6-я Кожуховская ул., 15\nМосква\nРоссия\n115193', 'name': 'Pyaterochka', 'sourceInfo': {'deviceTag': 806641417}, 'locationConfidence': 80.10061}, 'duration': {'startTimestampMs': '1585757705753', 'endTimestampMs': '1585758189978'}, 'placeConfidence': 'MEDIUM_CONFIDENCE', 'centerLatE7': 557072080, 'centerLngE7': 376738040, 'visitConfidence': 96, 'otherCandidateLocations': [{'latitudeE7': 557072890, 'longitudeE7': 376736742, 'placeId': 'ChIJv0wlC860SkERxK-TsSZOiMc', 'locationConfidence': 9.407087}, {'latitudeE7': 557106046, 'longitudeE7': 376726826, 'placeId': 'ChIJ-cKTQtK0SkEREb6hY79MdtA', 'locationConfidence': 5.344596}, {'latitudeE7': 557071190, 'longitudeE7': 376767540, 'placeId': 'ChIJ-YArIs60SkERAAAAAAAAAAA', 'semanticType': 'TYPE_HOME', 'locationConfidence': 2.4526207}, {'latitudeE7': 557054123, 'longitudeE7': 376748285, 'placeId': 'ChIJUVF9WM60Sk
# ...

# %%
for el in loaded_json['timelineObjects'][1]['placeVisit']['location']:
    print(el)
# Out:
# latitudeE7
# longitudeE7
# placeId
# address
# name
# sourceInfo
# locationConfidence

# %%
for el in loaded_json['timelineObjects'][3]['placeVisit']['location']:
    print(el)
# Out:
# latitudeE7
# longitudeE7
# placeId
# address
# semanticType
# sourceInfo
# locationConfidence

# %%
for el in loaded_json['timelineObjects'][0]['activitySegment']:
    print(el)
# Out:
# startLocation
# endLocation
# duration
# distance
# activityType
# confidence
# activities
# waypointPath
# simplifiedRawPath

# %%
print(loaded_json['timelineObjects'][2])
# Out:
# {'activitySegment': {'startLocation': {'latitudeE7': 557068777, 'longitudeE7': 376739113}, 'endLocation': {'latitudeE7': 557074825, 'longitudeE7': 376758487}, 'duration': {'startTimestampMs': '1585758189978', 'endTimestampMs': '1585758312263'}, 'distance': 138, 'activityType': 'WALKING', 'confidence': 'HIGH', 'activities': [{'activityType': 'WALKING', 'probability': 94.14697289466858}, {'activityType': 'IN_PASSENGER_VEHICLE', 'probability': 3.226548433303833}, {'activityType': 'STILL', 'probability': 1.147639099508524}, {'activityType': 'CYCLING', 'probability': 0.6597621832042933}, {'activityType': 'IN_BUS', 'probability': 0.4799535498023033}, {'activityType': 'RUNNING', 'probability': 0.1305819023400545}, {'activityType': 'IN_TRAM', 'probability': 0.08964810403995216}, {'activityType': 'SKIING', 'probability': 0.04612550837919116}, {'activityType': 'MOTORCYCLING', 'probability': 0.03353310457896441}, {'activityType': 'IN_FERRY', 'probability': 0.019202151452191174}, {'activityType'
# ...

# %%
print(loaded_json['timelineObjects'][3])
# Out:
# {'placeVisit': {'location': {'latitudeE7': 557071190, 'longitudeE7': 376767540, 'placeId': 'ChIJ-YArIs60SkERAAAAAAAAAAA', 'address': '', 'semanticType': 'TYPE_HOME', 'sourceInfo': {'deviceTag': 806641417}, 'locationConfidence': 92.06897}, 'duration': {'startTimestampMs': '1585758312263', 'endTimestampMs': '1585819888419'}, 'placeConfidence': 'HIGH_CONFIDENCE', 'centerLatE7': 557072390, 'centerLngE7': 376768505, 'visitConfidence': 84, 'otherCandidateLocations': [{'latitudeE7': 557067570, 'longitudeE7': 376773120, 'placeId': 'ChIJ8WRqLs60SkER6RPMMQplkJQ', 'locationConfidence': 3.790281}, {'latitudeE7': 557106046, 'longitudeE7': 376726826, 'placeId': 'ChIJ-cKTQtK0SkEREb6hY79MdtA', 'locationConfidence': 1.7266027}, {'latitudeE7': 557072334, 'longitudeE7': 376762907, 'placeId': 'ChIJtSp0GM60SkERgjJzq30ZuOw', 'locationConfidence': 0.9540245}, {'latitudeE7': 557080357, 'longitudeE7': 376776012, 'placeId': 'ChIJSdOi3tG0SkERUzgJhR4vM9w', 'locationConfidence': 0.4011668}], 'editConfirmationSta
# ...

# %%
print(loaded_json['timelineObjects'][200])
# Out:
# {'placeVisit': {'location': {'latitudeE7': 557071190, 'longitudeE7': 376767540, 'placeId': 'ChIJ-YArIs60SkERAAAAAAAAAAA', 'address': '', 'semanticType': 'TYPE_HOME', 'sourceInfo': {'deviceTag': 806641417}, 'locationConfidence': 88.56575}, 'duration': {'startTimestampMs': '1587387682967', 'endTimestampMs': '1587390921342'}, 'placeConfidence': 'MEDIUM_CONFIDENCE', 'centerLatE7': 557071810, 'centerLngE7': 376769680, 'visitConfidence': 87, 'otherCandidateLocations': [{'latitudeE7': 557067570, 'longitudeE7': 376773120, 'placeId': 'ChIJ8WRqLs60SkER6RPMMQplkJQ', 'locationConfidence': 3.8193169}, {'latitudeE7': 557106046, 'longitudeE7': 376726826, 'placeId': 'ChIJ-cKTQtK0SkEREb6hY79MdtA', 'locationConfidence': 3.3659291}, {'latitudeE7': 557072334, 'longitudeE7': 376762907, 'placeId': 'ChIJKVmV5GO1SkEROhK9shOjTrA', 'locationConfidence': 1.2992551}, {'latitudeE7': 557072334, 'longitudeE7': 376762907, 'placeId': 'ChIJtSp0GM60SkERgjJzq30ZuOw', 'locationConfidence': 0.8696982}, {'latitudeE7': 557
# ...

# %%
print(loaded_json['timelineObjects'][199])
# Out:
# {'activitySegment': {'startLocation': {'latitudeE7': 557032602, 'longitudeE7': 376772320, 'sourceInfo': {'deviceTag': 806641417}}, 'endLocation': {'latitudeE7': 557068527, 'longitudeE7': 376772818, 'sourceInfo': {'deviceTag': 806641417}}, 'duration': {'startTimestampMs': '1587387440467', 'endTimestampMs': '1587387682967'}, 'distance': 399, 'activityType': 'WALKING', 'confidence': 'HIGH', 'activities': [{'activityType': 'WALKING', 'probability': 92.36656427383423}, {'activityType': 'IN_PASSENGER_VEHICLE', 'probability': 2.8369970619678497}, {'activityType': 'IN_BUS', 'probability': 2.6438960805535316}, {'activityType': 'STILL', 'probability': 0.9704448282718658}, {'activityType': 'CYCLING', 'probability': 0.41877496987581253}, {'activityType': 'RUNNING', 'probability': 0.2636718796566129}, {'activityType': 'IN_TRAM', 'probability': 0.16296582762151957}, {'activityType': 'IN_SUBWAY', 'probability': 0.1423426205292344}, {'activityType': 'IN_TRAIN', 'probability': 0.08036837098188698}, {
# ...

# %%
print(loaded_json['timelineObjects'][50])
# Out:
# {'activitySegment': {'startLocation': {'latitudeE7': 557074147, 'longitudeE7': 376770647}, 'endLocation': {'latitudeE7': 556960950, 'longitudeE7': 376638393}, 'duration': {'startTimestampMs': '1586275896115', 'endTimestampMs': '1586278347689'}, 'distance': 4306, 'activityType': 'WALKING', 'confidence': 'HIGH', 'activities': [{'activityType': 'WALKING', 'probability': 97.16458320617676}, {'activityType': 'STILL', 'probability': 1.1423194780945778}, {'activityType': 'IN_PASSENGER_VEHICLE', 'probability': 0.8049435913562775}, {'activityType': 'RUNNING', 'probability': 0.3526469226926565}, {'activityType': 'IN_BUS', 'probability': 0.3175697522237897}, {'activityType': 'CYCLING', 'probability': 0.08765775710344315}, {'activityType': 'IN_SUBWAY', 'probability': 0.07480323547497392}, {'activityType': 'IN_TRAM', 'probability': 0.02030490868492052}, {'activityType': 'SKIING', 'probability': 0.01617215311853215}, {'activityType': 'MOTORCYCLING', 'probability': 0.007016101153567433}, {'activity
# ...
