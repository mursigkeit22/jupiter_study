# %%
# https://mapcruzin.com/free-russia-european-country-city-place-gis-shapefiles.htm
# http://download.geofabrik.de/russia/central-fed-district.html

# %%
import pandas as pd
import numpy as np
import geopandas as gp
import shapely.geometry as sg
import datetime as dt
from matplotlib import cm
from matplotlib.lines import Line2D
import json

# %%
world_map = gp.read_file('TM_WORLD_BORDERS-0.3\TM_WORLD_BORDERS-0.3.shp')

world_map.plot()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Lera\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# Russia_Boundary = gp.read_file('Russia_Boundary\Russia_Boundary.shp')

# Russia_Boundary.plot(figsize=(20,10))

# base = Russia_Boundary.plot(color='white', edgecolor='silver', figsize=(16,16))
# base.set_xlim(25, 200)
# base.set_ylim(40, 100)
# ax = box_only.plot(ax=base, marker='o', markersize=8)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Russia_Boundary\Russia_Boundary.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-3-588fcc505668> in <module>
# ----> 1 Russia_Boundary = gp.read_file('Russia_Boundary\Russia_Boundary.shp')
#       2
#       3 # Russia_Boundary.plot(figsize=(20,10))
#       4
#       5 base = Russia_Boundary.plot(color='white', edgecolor='silver', figsize=(16,16))
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
# ...

# %%
moscow_build = gp.read_file('mosbld\mosbld.shp')

moscow_build.plot()

# %%
world = gp.read_file(gp.datasets.get_path('naturalearth_lowres'))

# %%
ax = world[world.continent == 'Asia'].plot(
    color='white', edgecolor='black')

# %%
gp.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
city = gp.read_file(gp.datasets.get_path('naturalearth_cities'))

# %%
ax = city.plot(
    color='white', edgecolor='black')
