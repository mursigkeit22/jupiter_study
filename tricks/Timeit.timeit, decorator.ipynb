# %% [markdown]
# https://realpython.com/python-sleep/

# %%
import sys
import time
import requests

# %%
sys.version
# Out:
# '3.6.8 |Anaconda, Inc.| (default, Feb 21 2019, 18:30:04) [MSC v.1916 64 bit (AMD64)]'

# %%
sys.version # обновила 30.10.19
# Out:
# '3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]'

# %% [markdown]
# ### How timeit works
#
# % line
#
# %% sell
#
# -n number of loops
#
# -r number of loops

# %%
# %%timeit
n = 1
time.sleep(n)
print('slept', n, 'sec')
# Out:
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# 1 s ± 4.87 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit -n 2
n = 1
time.sleep(n)
print('slept', n, 'sec')
# Out:
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# 1 s ± 2.35 ms per loop (mean ± std. dev. of 7 runs, 2 loops each)

# %%
# %%timeit -r 3
n = 1
time.sleep(n)
print('slept', n, 'sec')
# Out:
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# 1.01 s ± 6.22 ms per loop (mean ± std. dev. of 3 runs, 1 loop each)

# %%
# %%timeit -r 3 -n 2
n = 1
time.sleep(n)
print('slept', n, 'sec')
# Out:
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# 1 s ± 3.51 ms per loop (mean ± std. dev. of 3 runs, 2 loops each)

# %%
#The default number of times that timeit will run your code is one million
# %timeit print('a')
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# ...

# %%
# Command-Line Interface:
#$ python3 -m timeit -n 3 "import time; time.sleep(3)"

# %% [markdown]
# ### In a standard Python interpreter

# %%
import timeit
def sl(n):
    time.sleep(n)
    print('slept', n, 'sec') 
timeit.repeat('sl(1)', "from __main__ import sl",
                  number=3)
# Out:
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# [3.0032880999988265,
#  3.0019336999994266,
#  3.0026223000004393,
#  3.0052893000010954,
#  3.0029492000012397]

# %%
def sl(n):
    time.sleep(n)
    print('slept', n, 'sec') 
timeit.timeit('sl(1)', "from __main__ import sl",
                 number = 1 )
# Out:
# slept 1 sec
# 1.014857199999824

# %%
timeit.repeat(stmt='sl(1)', setup='from __main__ import sl', repeat=5, number=1)
# Out:
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# [1.0011014999981853,
#  1.000676100000419,
#  1.0005931999985478,
#  1.0013398000010056,
#  1.0022241000006034]

# %%
timeit.repeat(stmt='sl(1)', setup='from __main__ import sl', repeat=5, number=2)
# Out:
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# slept 1 sec
# [2.002619999999297,
#  2.0009509999981674,
#  2.0020242999999027,
#  2.0016911000020627,
#  2.0007504999994126]

# %% [markdown]
# ### Декоратор

# %% [markdown]
# sleep() is your decorator. It accepts a timeout value and the number of times it should retry, which defaults to 3.
#
# Inside sleep() is another function, the_real_decorator(), which accepts the decorated function.
#
# Finally, the innermost function wrapper() accepts the arguments and keyword arguments that you pass to the decorated function.  You use a while loop to retry calling the function. If there’s an exception, then you call time.sleep(), increment the retries counter, and try running the function again.

# %%
def sleep(timeout, retry=3):
    def the_real_decorator(function):
        def wrapper(*args, **kwargs):
            retries = 0
            while retries < retry:
                try:
                    value = function(*args, **kwargs)
                    if value is None:
                        return
                except:
                    print(f'Sleeping for {timeout} seconds')
                    time.sleep(timeout)
                    retries += 1
        return wrapper
    return the_real_decorator

# %% [markdown]
# #### original function - without decorator:
#
# Here you create uptime_bot(), which takes a URL as its argument. The function then attempts to open that URL. If there’s an error, then the program catches it and prints out the error.
#
# If no errors occur, then your code prints out that all is well. Regardless of what happens, your program will sleep for 60 seconds. This means that you only access the website once every minute.

# %%
def uptime_bot(url):
    while True:
        try:
            requests.get(url)
        except requests.ConnectionError as e:
            print(f'HTTPConnectionError: {e.args} for {url}')
        except requests.RequestException as e:
            print(f'RequestException: {e.args} for {url}')
        else:
            # Website is up
            print(f'{url} is up')
        time.sleep(10)


if __name__ == '__main__':
    url = 'http://www.googl'
    url = 'ht//www.googl'
    url = 'http://www.google.com'

    uptime_bot(url)
# Out:
# http://www.google.com is up
# http://www.google.com is up
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-2a83a83052ab> in <module>
#      18     url = 'http://www.google.com'
#      19
# ---> 20     uptime_bot(url)
#
# <ipython-input-23-2a83a83052ab> in uptime_bot(url)
#      10             # Website is up
#      11             print(f'{url} is up')
# ---> 12         time.sleep(10)
#      13
#      14
#
# KeyboardInterrupt:

# %% [markdown]
# There are times when you need to retry a function that has failed. One popular use case for this is when you need to retry a file download because the server was busy. You usually won’t want to make a request to the server too often, so adding a Python sleep() call between each request is desirable.

# %% [markdown]
# Now rewrite uptime_bot() to use your new decorator:

# %%
@sleep(3)
def uptime_bot(url):
    try:
        requests.get(url)
    except requests.ConnectionError as e:
        print(f'HTTPConnectionError: {e.args} for {url}')
        # Re-raise the exception for the decorator
        raise requests.ConnectionError
    except requests.RequestException as e:
        print(f'RequestException: {e.args} for {url}')
        # Re-raise the exception for the decorator
        raise requests.RequestException
    else:
        # Website is up
        print(f'{url} is up')

if __name__ == '__main__':
    url = 'http://www.google.com/py'
    url = 'http://www.googl'
    url = 'ht//www.googl'
    uptime_bot(url)
# Out:
# RequestException: ("Invalid URL 'ht//www.googl': No schema supplied. Perhaps you meant http://ht//www.googl?",) for ht//www.googl
# Sleeping for 3 seconds
# RequestException: ("Invalid URL 'ht//www.googl': No schema supplied. Perhaps you meant http://ht//www.googl?",) for ht//www.googl
# Sleeping for 3 seconds
# RequestException: ("Invalid URL 'ht//www.googl': No schema supplied. Perhaps you meant http://ht//www.googl?",) for ht//www.googl
# Sleeping for 3 seconds
