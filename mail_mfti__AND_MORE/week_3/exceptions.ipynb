# %% [markdown]
# https://docs.python.org/3.6/library/exceptions.html

# %%
import os.path
import traceback

# %%
with open('missing_file.txt') as f:
        content = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-ef4f1729e576> in <module>
# ----> 1 with open('missing_file.txt') as f:
#       2         content = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'missing_file.txt'

# %%
try:
    with open('missing_file.txt') as f:
        content = f.read()
except OSError as err: # or FileNotFoundError or Exception
    print(err.args)
    print(err.errno, err.strerror)
# Out:
# (2, 'No such file or directory')
# 2 No such file or directory

# %%
path = 'missing_file.txt'
# path = 'existing_file.txt'

try: # в данном случае вся эта конструкция какая-то лишняя
    if not os.path.exists(path):
        raise ValueError ("file doesn't exist:", path)
except ValueError as err: 
    print(err.args[0], err.args[1])
print('work continues')
# Out:
# file doesn't exist: missing_file.txt
# work continues

# %%
path = 'missing_file.txt'

if not os.path.exists(path):
    raise ValueError ("file doesn't exist:", path)
print('work continues') # doesn't print
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-db2e69a589f8> in <module>
#       3
#       4 if not os.path.exists(path):
# ----> 5     raise ValueError ("file doesn't exist:", path)
#       6 print('work continues')
#
# ValueError: ("file doesn't exist:", 'missing_file.txt')

# %%
path = 'missing_file.txt'
if not os.path.exists(path):
    print("file doesn't exist:", path)
print('work continues')
# Out:
# file doesn't exist: missing_file.txt
# work continues

# %% [markdown]
# #### стек вызовов

# %%
try:
    with open('missing_file.txt') as f:
        content = f.read()
except OSError as err:
    traceback.print_exc()
#     trace = traceback.print_exc()
#     print(trace)
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-32-c54710ba3549>", line 2, in <module>
#     with open('missing_file.txt') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'missing_file.txt'

# %%
with open('missing_file.txt') as f:
        content = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-ef4f1729e576> in <module>
# ----> 1 with open('missing_file.txt') as f:
#       2         content = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'missing_file.txt'

# %% [markdown]
# #### Инструкция raise

# %%
try:
    raw = input('enter your number: ')
    if not raw.isdigit():
        raise ValueError('bad number', raw)
except ValueError as err:
    print('invalid number!', err)
# Out:
# enter your number: a
# invalid number! ('bad number', 'a')

# %%
try:
    raw = input('enter your number: ')
    if not raw.isdigit():
        raise ValueError('bad number', raw)
except ValueError as err:
    print('invalid number!', err)
    raise # рейз без параметров - можно вывести какую-то инфу на экран и 
    # делегировать обработку этого исключения другой функции - которая вызвала эту функцию
# Out:
# enter your number: a
# invalid number! ('bad number', 'a')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-7be359cc2a1d> in <module>
#       2     raw = input('enter your number: ')
#       3     if not raw.isdigit():
# ----> 4         raise ValueError('bad number', raw)
#       5 except ValueError as err:
#       6     print('invalid number!', err)
#
# ValueError: ('bad number', 'a')

# %% [markdown]
# #### raise from Exception

# %%
try:
    raw = input('enter your number: ')
    if not raw.isdigit():
        raise ValueError('bad number', raw)
except ValueError as err:
    print('invalid number!', err.args)
    raise TypeError('error!') from err
# Out:
# enter your number: q
# invalid number! ('bad number', 'q')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-7f582e043b9e> in <module>
#       3     if not raw.isdigit():
# ----> 4         raise ValueError('bad number', raw)
#       5 except ValueError as err:
#
# ValueError: ('bad number', 'q')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-7f582e043b9e> in <module>
#       5 except ValueError as err:
#       6     print('invalid number!', err.args)
# ----> 7     raise TypeError('error!') from err
#
# TypeError: error!

# %% [markdown]
# #### Инструкция assert

# %%
assert True

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-45-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %%
assert 1 == 1

# %%
assert 1 == 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-47-e99f91a18d62> in <module>
# ----> 1 assert 1 == 0
#
# AssertionError:

# %%
a = 1
b = 1
assert a == b, 'a != b'

# %%
a = 1
b = 0
assert a == b, 'a != b'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-49-ea841b2c8a41> in <module>
#       1 a = 1
#       2 b = 0
# ----> 3 assert a == b, 'a != b'
#
# AssertionError: a != b

# %%
def get_user_by_id(id):
    assert isinstance(id, int), 'id must be an integer'
    print('search is on')

if __name__ == '__main__':
    get_user_by_id('ty')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-51-df0cae231f8f> in <module>
#       4
#       5 if __name__ == '__main__':
# ----> 6     get_user_by_id('ty')
#
# <ipython-input-51-df0cae231f8f> in get_user_by_id(id)
#       1 def get_user_by_id(id):
# ----> 2     assert isinstance(id, int), 'id must be an integer'
#       3     print('search is on')
#       4
#       5 if __name__ == '__main__':
#
# AssertionError: id must be an integer

# %% [markdown]
#  в командной строке флаг -О отключает ассерты
#
#     python -O test_assert.py

# %%
# %%timeit
# Out:
# UsageError: %%timeit is a cell magic, but the cell body is empty. Did you mean the line magic %timeit (single %)?

# %%
# %%timeit
my_dict = {'a':1}
for _ in range(1000):
    try:
        my_dict['b']
    except KeyError:
        pass
# Out:
# 325 µs ± 11.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
my_dict = {'a':1}
for _ in range(1000):
    if 'b' in my_dict:
        _ = my_dict['b']
# микросекунда 10 в -6
# Out:
# 53.2 µs ± 3.35 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
path = 'missing_file.txt'
print(os.path.exists(path))
path = 'existing_file.txt'
print(os.path.exists(path))
# Out:
# False
# True
