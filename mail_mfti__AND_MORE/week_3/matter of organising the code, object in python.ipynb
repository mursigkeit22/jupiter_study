# %%
class Human:
    pass


class Robot:
    """ this class lets you to create Robots"""


print(Robot)
print(dir(Robot))
# Out:
# <class '__main__.Robot'>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__']

# %%
class Planet:
    pass

# %%
planet = Planet()

# %%
print(planet)

# %%
planet

# %%
solar_system = {}
for i in range(8):
    planet = Planet()
    solar_system[planet] = True
print(solar_system)
# Out:
# {<__main__.Planet object at 0x000002466F703748>: True, <__main__.Planet object at 0x000002466F703828>: True, <__main__.Planet object at 0x000002466F703860>: True, <__main__.Planet object at 0x000002466F703898>: True, <__main__.Planet object at 0x000002466F7038D0>: True, <__main__.Planet object at 0x000002466F703908>: True, <__main__.Planet object at 0x000002466F703940>: True, <__main__.Planet object at 0x000002466F703978>: True}

# %%
a = 5 #id() returns the object’s memory address.
id(a)
# Out:
# 1505276256

# %%
a = a+1
id(a)
# Out:
# 1505276288

# %%
my_list = [1, 2, 3]
id(my_list)
# Out:
# 2501540552904

# %%
my_list.append(4)
print(my_list)
print(id(my_list))
# Out:
# [1, 2, 3, 4]
# 2501540552904

# %%
id(planet)
# Out:
# 2501540591992

# %%
first = 5
second = 5
first is second # is returns True if and only if two objects have the same memory address.
# Out:
# True

# %%
planet

# %%
id(planet)
# Out:
# 2501540591992

# %%
planet.__repr__()
# Out:
# '<__main__.Planet object at 0x000002466F703978>'

# %%
import sys
format(id(planet), '#010x' if sys.maxsize.bit_length() <= 32 else '#18x')
# Out:
# '     0x2466f703978'

# %%
format(id(planet), '#010x')
# Out:
# '0x2466f703978'

# %%
x = 1000
y = 499 + 501
y is x
# Out:
# False

# %%
y == x
# Out:
# True

# %%
first_str = 'aaa'
second_str = 'aaa'
first_str==second_str
# Out:
# True

# %%
first_str is second_str
# Out:
# True

# %%
first_str = 'aaa'
second_str = 'aa'+'a'
first_str==second_str
# Out:
# True

# %%
first_str is second_str
# Out:
# True

# %%
first_str = 'щщщ'
second_str = 'щщщ'
first_str==second_str
# Out:
# True

# %%
first_str is second_str
# Out:
# False

# %%
first_str = 'щ'
second_str = 'щ'
first_str==second_str
# Out:
# True

# %%
first_str is second_str
# Out:
# False

# %%
Planet.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__dict__': <attribute '__dict__' of 'Planet' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Planet' objects>,
#               '__doc__': None})

# %%
planet.__dict__
# Out:
# {}

# %%
Planet.class_atr = 'class_hop'

# %%
Planet.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__dict__': <attribute '__dict__' of 'Planet' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Planet' objects>,
#               '__doc__': None,
#               'class_atr': 'class_hop'})

# %%
planet.class_attr = 'instance_hop'

# %%
planet.__dict__
# Out:
# {'class_atr': 'instance_hop'}

# %%
planet.class_attr, planet.__dict__['class_attr']
# Out:
# ('instance_hop', 'instance_hop')

# %%
planet.only_instance_attr = 'only_instance_hop'

# %%
planet.__dict__['only_instance_attr'] #
# Out:
# 'only_instance_hop'

# %%
planet.__class__
# Out:
# __main__.Planet

# %%
Planet.__bases__
# Out:
# (object,)
