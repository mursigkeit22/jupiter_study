# %% [markdown]
# https://stackoverflow.com/questions/12101958/how-to-keep-track-of-class-instances?noredirect=1&lq=1
#
# https://stackoverflow.com/questions/16686788/python-how-to-kill-a-class-instance-object
#
# https://pythonru.com/primery/primery-raboty-s-klassami-v-python#toc-4
#
# How many references:
#
# https://rushter.com/blog/python-garbage-collector/

# %%
import sys
import gc

# %%
class Employee:
    """Базовый класс для всех сотрудников"""
    emp_count = 0

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        Employee.emp_count += 1

    @classmethod # обращаемся к классу, а не к экземпляру
    def display_count(cls):
        print('Всего сотрудников: %d' % Employee.emp_count)

    def display_employee(self):
        print('Имя: {}. Зарплата: {}'.format(self.name, self.salary))

    def __del__(self): #when the code is about to end the class Employee is no longer required and so,
# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.
        class_name = self.__class__.__name__
        print('{} уничтожен'.format(self.name))

# %%
emp1 = Employee("Андрей", 2000)
emp2 = Employee("Мария", 5000)
emp3 = Employee("Фаина", 7000)

# %%
print(id(emp1))
# Out:
# 2353563713488

# %%
emp1.age = 27  # Добавит атрибут 'age'.

# %%
del emp1.salary

# %%
emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c7022b58ca32> in <module>
# ----> 1 emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей
#
# <ipython-input-2-6b73921ec63e> in display_employee(self)
#      13
#      14     def display_employee(self):
# ---> 15         print('Имя: {}. Зарплата: {}'.format(self.name, self.salary))
#      16
#      17     def __del__(self): #when the code is about to end the class Employee is no longer required and so,
#
# AttributeError: 'Employee' object has no attribute 'salary'

# %%
Employee.display_count()
# Out:
# Всего сотрудников: 3

# %%
emp1.display_count()# тоже сработает, хотя это и экземпляр
# Out:
# Всего сотрудников: 3

# %%
print("Количество сотрудников: %d" % Employee.emp_count)
# Out:
# Количество сотрудников: 3

# %%
emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.
#он сам ничего не удаляет
# Out:
# Андрей уничтожен

# %%
print(id(emp1))
# Out:
# 2353563713488

# %%
print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует
# Out:
# True

# %%
print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути
# Out:
# 27

# %%
setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28
print(getattr(emp1, 'age'))
# Out:
# 28

# %%
delattr(emp1, 'age')  # удаляет атрибут 'age'

# %%
print("Employee.__doc__:", Employee.__doc__)
# Out:
# Employee.__doc__: Базовый класс для всех сотрудников

# %%
print("Employee.__name__:", Employee.__name__)
# Out:
# Employee.__name__: Employee

# %%
print("Employee.__module__:", Employee.__module__)
# Out:
# Employee.__module__: __main__

# %%
print("Employee.__bases__:", Employee.__bases__)
# Out:
# Employee.__bases__: (<class 'object'>,)

# %%
print("Employee.__dict__:", Employee.__dict__)
# Out:
# Employee.__dict__: {'__module__': '__main__', '__doc__': 'Базовый класс для всех сотрудников', 'emp_count': 3, '__init__': <function Employee.__init__ at 0x000001E6E7CA1268>, 'display_count': <classmethod object at 0x000001E6EA05B2B0>, 'display_employee': <function Employee.display_employee at 0x000001E6EA043488>, '__del__': <function Employee.__del__ at 0x000001E6EA043510>, '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>}

# %%
print(emp2.__dict__)
# Out:
# {'name': 'Мария', 'salary': 5000}

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'class Employee:\n    """Базовый класс для всех сотрудников"""\n    emp_count = 0\n\n    def __init__(self, name, salary):\n        self.name = name\n        self.salary = salary\n        Employee.emp_count += 1\n\n    @classmethod # обращаемся к классу, а не к экземпляру\n    def display_count(cls):\n        print(\'Всего сотрудников: %d\' % Employee.emp_count)\n\n    def display_employee(self):\n        print(\'Имя: {}. Зарплата: {}\'.format(self.name, self.salary))\n\n    def __del__(self): #when the code is about to end the class Employee is no longer required and so,\n# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.\n        class_name = self.__class__.__name__\n        print(\'{} уничтожен\'.format(class_name))',
#   'emp1 = Employee("Андрей", 2000)\nemp2 = Employee("Мария", 5000)\nemp3 = Employee("Фаина", 7000)',
#   'print(id(emp1))',
#   "emp1.age = 27  # Добавит атрибут 'age'.",
#   'del emp1.salary ',
#   'emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей',
#   'Employee.display_count()',
#   'emp1.display_count()# тоже сработает, хотя это и экземпляр',
#   'print("Количество сотрудников: %d" % Employee.emp_count)',
#   'emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.\n#он сам ничего не удаляет',
#   "print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует",
#   "print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути",
#   "setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28\nprint(getattr(emp1, 'age'))",
#   "delattr(emp1, 'age')  # удаляет атрибут 'age'",
#   'print("Employee.__doc__:", Employee.__doc__)',
#   'print("Employee.__name__:", Employee.__name__)',
#   'print("Employee.__module__:", Employee.__module__)',
#   'print("Employee.__bases__:", Employee.__bases__)',
#   'print("Employee.__dict__:", Employee.__dict__)',
#   'print(emp2.__dict__)',
#   'locals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\Lera\\Desktop\\jupiter\\mail_mfti\\week_3'],
#  'In': ['',
#   'class Employee:\n    """Базовый класс для всех сотрудников"""\n    emp_count = 0\n\n    def __init__(self, name, salary):\n        self.name = name\n        self.salary = salary\n        Employee.emp_count += 1\n\n    @classmethod # обращаемся к классу, а не к экземпляру\n    def display_count(cls):\n        print(\'Всего сотрудников: %d\' % Employee.emp_count)\n\n    def display_employee(self):\n        print(\'Имя: {}. Зарплата: {}\'.format(self.name, self.salary))\n\n    def __del__(self): #when the code is about to end the class Employee is no longer required and so,\n# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.\n        class_name = self.__class__.__name__\n        print(\'{} уничтожен\'.format(class_name))',
#   'emp1 = Employee("Андрей", 2000)\nemp2 = Employee("Мария", 5000)\nemp3 = Employee("Фаина", 7000)',
#   'print(id(emp1))',
#   "emp1.age = 27  # Добавит атрибут 'age'.",
#   'del emp1.salary ',
#   'emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей',
#   'Employee.display_count()',
#   'emp1.display_count()# тоже сработает, хотя это и экземпляр',
#   'print("Количество сотрудников: %d" % Employee.emp_count)',
#   'emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.\n#он сам ничего не удаляет',
#   "print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует",
#   "print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути",
#   "setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28\nprint(getattr(emp1, 'age'))",
#   "delattr(emp1, 'age')  # удаляет атрибут 'age'",
#   'print("Employee.__doc__:", Employee.__doc__)',
#   'print("Employee.__name__:", Employee.__name__)',
#   'print("Employee.__module__:", Employee.__module__)',
#   'print("Employee.__bases__:", Employee.__bases__)',
#   'print("Employee.__dict__:", Employee.__dict__)',
#   'print(emp2.__dict__)',
#   'locals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001E6E7C60A90>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1e6e7cbe6a0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1e6e7cbe6a0>,
#  '_': '',
#  '__': '',
#  '___': '',
#  'pd': <module 'pandas' from 'C:\\Users\\Lera\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>,
#  'np': <module 'numpy' from 'C:\\Users\\Lera\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>,
#  '_i': 'print(emp2.__dict__)',
#  '_ii': 'print("Employee.__dict__:", Employee.__dict__)',
#  '_iii': 'print("Employee.__bases__:", Employee.__bases__)',
#  '_i1': 'class Employee:\n    """Базовый класс для всех сотрудников"""\n    emp_count = 0\n\n    def __init__(self, name, salary):\n        self.name = name\n        self.salary = salary\n        Employee.emp_count += 1\n\n    @classmethod # обращаемся к классу, а не к экземпляру\n    def display_count(cls):\n        print(\'Всего сотрудников: %d\' % Employee.emp_count)\n\n    def display_employee(self):\n        print(\'Имя: {}. Зарплата: {}\'.format(self.name, self.salary))\n\n    def __del__(self): #when the code is about to end the class Employee is no longer required and so,\n# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.\n        class_name = self.__class__.__name__\n        print(\'{} уничтожен\'.format(class_name))',
#  'Employee': __main__.Employee,
#  '_i2': 'emp1 = Employee("Андрей", 2000)\nemp2 = Employee("Мария", 5000)\nemp3 = Employee("Фаина", 7000)',
#  'emp1': <__main__.Employee at 0x1e6ea022a90>,
#  'emp2': <__main__.Employee at 0x1e6ea022b00>,
#  'emp3': <__main__.Employee at 0x1e6ea022198>,
#  '_i3': 'print(id(emp1))',
#  '_i4': "emp1.age = 27  # Добавит атрибут 'age'.",
#  '_i5': 'del emp1.salary ',
#  '_i6': 'emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей',
#  '_i7': 'Employee.display_count()',
#  '_i8': 'emp1.display_count()# тоже сработает, хотя это и экземпляр',
#  '_i9': 'print("Количество сотрудников: %d" % Employee.emp_count)',
#  '_i10': 'emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.\n#он сам ничего не удаляет',
#  '_i11': "print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует",
#  '_i12': "print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути",
#  '_i13': "setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28\nprint(getattr(emp1, 'age'))",
#  '_i14': "delattr(emp1, 'age')  # удаляет атрибут 'age'",
#  '_i15': 'print("Employee.__doc__:", Employee.__doc__)',
#  '_i16': 'print("Employee.__name__:", Employee.__name__)',
#  '_i17': 'print("Employee.__module__:", Employee.__module__)',
#  '_i18': 'print("Employee.__bases__:", Employee.__bases__)',
#  '_i19': 'print("Employee.__dict__:", Employee.__dict__)',
#  '_i20': 'print(emp2.__dict__)',
#  '_i21': 'locals()'}

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'class Employee:\n    """Базовый класс для всех сотрудников"""\n    emp_count = 0\n\n    def __init__(self, name, salary):\n        self.name = name\n        self.salary = salary\n        Employee.emp_count += 1\n\n    @classmethod # обращаемся к классу, а не к экземпляру\n    def display_count(cls):\n        print(\'Всего сотрудников: %d\' % Employee.emp_count)\n\n    def display_employee(self):\n        print(\'Имя: {}. Зарплата: {}\'.format(self.name, self.salary))\n\n    def __del__(self): #when the code is about to end the class Employee is no longer required and so,\n# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.\n        class_name = self.__class__.__name__\n        print(\'{} уничтожен\'.format(class_name))',
#   'emp1 = Employee("Андрей", 2000)\nemp2 = Employee("Мария", 5000)\nemp3 = Employee("Фаина", 7000)',
#   'print(id(emp1))',
#   "emp1.age = 27  # Добавит атрибут 'age'.",
#   'del emp1.salary ',
#   'emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей',
#   'Employee.display_count()',
#   'emp1.display_count()# тоже сработает, хотя это и экземпляр',
#   'print("Количество сотрудников: %d" % Employee.emp_count)',
#   'emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.\n#он сам ничего не удаляет',
#   "print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует",
#   "print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути",
#   "setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28\nprint(getattr(emp1, 'age'))",
#   "delattr(emp1, 'age')  # удаляет атрибут 'age'",
#   'print("Employee.__doc__:", Employee.__doc__)',
#   'print("Employee.__name__:", Employee.__name__)',
#   'print("Employee.__module__:", Employee.__module__)',
#   'print("Employee.__bases__:", Employee.__bases__)',
#   'print("Employee.__dict__:", Employee.__dict__)',
#   'print(emp2.__dict__)',
#   'locals()',
#   'globals()'],
#  '_oh': {21: {...}},
#  '_dh': ['C:\\Users\\Lera\\Desktop\\jupiter\\mail_mfti\\week_3'],
#  'In': ['',
#   'class Employee:\n    """Базовый класс для всех сотрудников"""\n    emp_count = 0\n\n    def __init__(self, name, salary):\n        self.name = name\n        self.salary = salary\n        Employee.emp_count += 1\n\n    @classmethod # обращаемся к классу, а не к экземпляру\n    def display_count(cls):\n        print(\'Всего сотрудников: %d\' % Employee.emp_count)\n\n    def display_employee(self):\n        print(\'Имя: {}. Зарплата: {}\'.format(self.name, self.salary))\n\n    def __del__(self): #when the code is about to end the class Employee is no longer required and so,\n# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.\n        class_name = self.__class__.__name__\n        print(\'{} уничтожен\'.format(class_name))',
#   'emp1 = Employee("Андрей", 2000)\nemp2 = Employee("Мария", 5000)\nemp3 = Employee("Фаина", 7000)',
#   'print(id(emp1))',
#   "emp1.age = 27  # Добавит атрибут 'age'.",
#   'del emp1.salary ',
#   'emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей',
#   'Employee.display_count()',
#   'emp1.display_count()# тоже сработает, хотя это и экземпляр',
#   'print("Количество сотрудников: %d" % Employee.emp_count)',
#   'emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.\n#он сам ничего не удаляет',
#   "print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует",
#   "print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути",
#   "setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28\nprint(getattr(emp1, 'age'))",
#   "delattr(emp1, 'age')  # удаляет атрибут 'age'",
#   'print("Employee.__doc__:", Employee.__doc__)',
#   'print("Employee.__name__:", Employee.__name__)',
#   'print("Employee.__module__:", Employee.__module__)',
#   'print("Employee.__bases__:", Employee.__bases__)',
#   'print("Employee.__dict__:", Employee.__dict__)',
#   'print(emp2.__dict__)',
#   'locals()',
#   'globals()'],
#  'Out': {21: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001E6E7C60A90>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1e6e7cbe6a0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1e6e7cbe6a0>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  'pd': <module 'pandas' from 'C:\\Users\\Lera\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>,
#  'np': <module 'numpy' from 'C:\\Users\\Lera\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>,
#  '_i': 'locals()',
#  '_ii': 'print(emp2.__dict__)',
#  '_iii': 'print("Employee.__dict__:", Employee.__dict__)',
#  '_i1': 'class Employee:\n    """Базовый класс для всех сотрудников"""\n    emp_count = 0\n\n    def __init__(self, name, salary):\n        self.name = name\n        self.salary = salary\n        Employee.emp_count += 1\n\n    @classmethod # обращаемся к классу, а не к экземпляру\n    def display_count(cls):\n        print(\'Всего сотрудников: %d\' % Employee.emp_count)\n\n    def display_employee(self):\n        print(\'Имя: {}. Зарплата: {}\'.format(self.name, self.salary))\n\n    def __del__(self): #when the code is about to end the class Employee is no longer required and so,\n# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.\n        class_name = self.__class__.__name__\n        print(\'{} уничтожен\'.format(class_name))',
#  'Employee': __main__.Employee,
#  '_i2': 'emp1 = Employee("Андрей", 2000)\nemp2 = Employee("Мария", 5000)\nemp3 = Employee("Фаина", 7000)',
#  'emp1': <__main__.Employee at 0x1e6ea022a90>,
#  'emp2': <__main__.Employee at 0x1e6ea022b00>,
#  'emp3': <__main__.Employee at 0x1e6ea022198>,
#  '_i3': 'print(id(emp1))',
#  '_i4': "emp1.age = 27  # Добавит атрибут 'age'.",
#  '_i5': 'del emp1.salary ',
#  '_i6': 'emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей',
#  '_i7': 'Employee.display_count()',
#  '_i8': 'emp1.display_count()# тоже сработает, хотя это и экземпляр',
#  '_i9': 'print("Количество сотрудников: %d" % Employee.emp_count)',
#  '_i10': 'emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.\n#он сам ничего не удаляет',
#  '_i11': "print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует",
#  '_i12': "print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути",
#  '_i13': "setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28\nprint(getattr(emp1, 'age'))",
#  '_i14': "delattr(emp1, 'age')  # удаляет атрибут 'age'",
#  '_i15': 'print("Employee.__doc__:", Employee.__doc__)',
#  '_i16': 'print("Employee.__name__:", Employee.__name__)',
#  '_i17': 'print("Employee.__module__:", Employee.__module__)',
#  '_i18': 'print("Employee.__bases__:", Employee.__bases__)',
#  '_i19': 'print("Employee.__dict__:", Employee.__dict__)',
#  '_i20': 'print(emp2.__dict__)',
#  '_i21': 'locals()',
#  '_21': {...},
#  '_i22': 'globals()'}

# %%
print(sys.getrefcount(emp2)) # # 2 references, 1 from the emp2 var and 1 from getrefcount
print(len(gc.get_referrers(emp2)))
# Out:
# 2
# 1

# %%
gc.get_referrers(emp2)
# Out:
# [{'__name__': '__main__',
#   '__doc__': 'Automatically created module for IPython interactive environment',
#   '__package__': None,
#   '__loader__': None,
#   '__spec__': None,
#   '__builtin__': <module 'builtins' (built-in)>,
#   '__builtins__': <module 'builtins' (built-in)>,
#   '_ih': ['',
#    'import sys\nimport gc',
#    'class Employee:\n    """Базовый класс для всех сотрудников"""\n    emp_count = 0\n\n    def __init__(self, name, salary):\n        self.name = name\n        self.salary = salary\n        Employee.emp_count += 1\n\n    @classmethod # обращаемся к классу, а не к экземпляру\n    def display_count(cls):\n        print(\'Всего сотрудников: %d\' % Employee.emp_count)\n\n    def display_employee(self):\n        print(\'Имя: {}. Зарплата: {}\'.format(self.name, self.salary))\n\n    def __del__(self): #when the code is about to end the class Employee is no longer required and so,\n# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.\n        class_name = self.__class__.__name__\n        print(\'{} уничтожен\'.format(self.name))',
#    'emp1 = Employee("Андрей", 2000)\nemp2 = Employee("Мария", 5000)\nemp3 = Employee("Фаина", 7000)',
#    'print(id(emp1))',
#    "emp1.age = 27  # Добавит атрибут 'age'.",
#    'del emp1.salary ',
#    'emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей',
#    'Employee.display_count()',
#    'emp1.display_count()# тоже сработает, хотя это и экземпляр',
#    'print("Количество сотрудников: %d" % Employee.emp_count)',
#    'emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.\n#он сам ничего не удаляет',
#    'print(id(emp1))',
#    "print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует",
#    "print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути",
#    "setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28\nprint(getattr(emp1, 'age'))",
#    "delattr(emp1, 'age')  # удаляет атрибут 'age'",
#    'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#    'print(sys.getrefcount(emp2))\n# print(gc.get_referrers(emp2))',
#    "for key, value in gc.get_referrers(emp2).items():\n    print(key)\n    print('---')\n    print(value)\n    print('---')\n    print('====')",
#    "for el in gc.get_referrers(emp2):\n    print(el)\n    print('---')\n    ",
#    'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#    'print(sys.getrefcount(emp2))\n# print(gc.get_referrers(emp2))',
#    "for el in gc.get_referrers(emp2):\n    for key, item in el.items()\n    print(key)\n    print('----')\n    print(item)\n    print('---')\n    ",
#    "for el in gc.get_referrers(emp2):\n    for key, item in el.items():\n    print(key)\n    print('----')\n    print(item)\n    print('---')\n    print('====')\n    ",
#    "for el in gc.get_referrers(emp2):\n    for key, item in el.items():\n        print(key)\n        print('----')\n        print(item)\n        print('---')\n        print('====')\n    ",
#    'print(gc.get_referrers())',
#    'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#    'print(sys.getrefcount(emp2))\nprint(len(gc.get_referrers(emp2)))',
#    'gc.get_referrers(emp2)'],
#   '_oh': {},
#   '_dh': ['C:\\Users\\Lera\\Desktop\\jupiter\\mail_mfti\\week_3'],
#   'In': ['',
#    'import sys\nimport gc',
#    'class Employee:\n    """Базовый класс для всех сотрудников"""\n    emp_count = 0\n\n    def __init__(self, name, salary):\n        self.name = name\n        self.salary = salary\n        Employee.emp_count += 1\n\n    @classmethod # обращаемся к классу, а не к экземпляру\n    def display_count(cls):\n        print(\'Всего сотрудников: %d\' % Employee.emp_count)\n\n    def display_employee(self):\n        print(\'Имя: {}. Зарплата: {}\'.format(self.name, self.salary))\n\n    def __del__(self): #when the code is about to end the class Employee is no longer required and so,\n# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.\n        class_name = self.__class__.__name__\n        print(\'{} уничтожен\'.format(self.name))',
#    'emp1 = Employee("Андрей", 2000)\nemp2 = Employee("Мария", 5000)\nemp3 = Employee("Фаина", 7000)',
#    'print(id(emp1))',
#    "emp1.age = 27  # Добавит атрибут 'age'.",
#    'del emp1.salary ',
#    'emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей',
#    'Employee.display_count()',
#    'emp1.display_count()# тоже сработает, хотя это и экземпляр',
#    'print("Количество сотрудников: %d" % Employee.emp_count)',
#    'emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.\n#он сам ничего не удаляет',
#    'print(id(emp1))',
#    "print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует",
#    "print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути",
#    "setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28\nprint(getattr(emp1, 'age'))",
#    "delattr(emp1, 'age')  # удаляет атрибут 'age'",
#    'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#    'print(sys.getrefcount(emp2))\n# print(gc.get_referrers(emp2))',
#    "for key, value in gc.get_referrers(emp2).items():\n    print(key)\n    print('---')\n    print(value)\n    print('---')\n    print('====')",
#    "for el in gc.get_referrers(emp2):\n    print(el)\n    print('---')\n    ",
#    'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#    'print(sys.getrefcount(emp2))\n# print(gc.get_referrers(emp2))',
#    "for el in gc.get_referrers(emp2):\n    for key, item in el.items()\n    print(key)\n    print('----')\n    print(item)\n    print('---')\n    ",
#    "for el in gc.get_referrers(emp2):\n    for key, item in el.items():\n    print(key)\n    print('----')\n    print(item)\n    print('---')\n    print('====')\n    ",
#    "for el in gc.get_referrers(emp2):\n    for key, item in el.items():\n        print(key)\n        print('----')\n        print(item)\n        print('---')\n        print('====')\n    ",
#    'print(gc.get_referrers())',
#    'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#    'print(sys.getrefcount(emp2))\nprint(len(gc.get_referrers(emp2)))',
#    'gc.get_referrers(emp2)'],
#   'Out': {},
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000223F91635C0>>,
#   'exit': <IPython.core.autocall.ZMQExitAutocall at 0x223f91de748>,
#   'quit': <IPython.core.autocall.ZMQExitAutocall at 0x223f91de748>,
#   '_': '',
#   '__': '',
#   '___': '',
#   'pd': <module 'pandas' from 'C:\\Users\\Lera\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>,
#   'np': <module 'numpy' from 'C:\\Users\\Lera\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>,
#   '_i': 'print(sys.getrefcount(emp2))\nprint(len(gc.get_referrers(emp2)))',
#   '_ii': 'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#   '_iii': 'print(gc.get_referrers())',
#   '_i1': 'import sys\nimport gc',
#   'sys': <module 'sys' (built-in)>,
#   'gc': <module 'gc' (built-in)>,
#   '_i2': 'class Employee:\n    """Базовый класс для всех сотрудников"""\n    emp_count = 0\n\n    def __init__(self, name, salary):\n        self.name = name\n        self.salary = salary\n        Employee.emp_count += 1\n\n    @classmethod # обращаемся к классу, а не к экземпляру\n    def display_count(cls):\n        print(\'Всего сотрудников: %d\' % Employee.emp_count)\n\n    def display_employee(self):\n        print(\'Имя: {}. Зарплата: {}\'.format(self.name, self.salary))\n\n    def __del__(self): #when the code is about to end the class Employee is no longer required and so,\n# it is ready to be destroyed.Before the class Employee is destroyed the __del__ method is called automatically.\n        class_name = self.__class__.__name__\n        print(\'{} уничтожен\'.format(self.name))',
#   'Employee': __main__.Employee,
#   '_i3': 'emp1 = Employee("Андрей", 2000)\nemp2 = Employee("Мария", 5000)\nemp3 = Employee("Фаина", 7000)',
#   'emp1': <__main__.Employee at 0x223fb543fd0>,
#   'emp2': <__main__.Employee at 0x223fb543f98>,
#   'emp3': <__main__.Employee at 0x223fb543ef0>,
#   '_i4': 'print(id(emp1))',
#   '_i5': "emp1.age = 27  # Добавит атрибут 'age'.",
#   '_i6': 'del emp1.salary ',
#   '_i7': 'emp1.display_employee() # вернет ошибку, так как мы удалили одно из полей',
#   '_i8': 'Employee.display_count()',
#   '_i9': 'emp1.display_count()# тоже сработает, хотя это и экземпляр',
#   '_i10': 'print("Количество сотрудников: %d" % Employee.emp_count)',
#   '_i11': 'emp1.__del__() # так вызывать этот метод не надо, потому что на самом деле он ничего при вызове не делает кроме печати.\n#он сам ничего не удаляет',
#   '_i12': 'print(id(emp1))',
#   '_i13': "print(hasattr(emp1, 'age'))  # возвращает true если атрибут 'age' существует",
#   '_i14': "print(getattr(emp1, 'age'))  # возвращает значение атрибута 'age', выпадает в ошибку, если атрибута нетути",
#   '_i15': "setattr(emp1, 'age', 28)  #устанавливает атрибут 'age' на 28\nprint(getattr(emp1, 'age'))",
#   '_i16': "delattr(emp1, 'age')  # удаляет атрибут 'age'",
#   '_i17': 'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#   '_i18': 'print(sys.getrefcount(emp2))\n# print(gc.get_referrers(emp2))',
#   '_i19': "for key, value in gc.get_referrers(emp2).items():\n    print(key)\n    print('---')\n    print(value)\n    print('---')\n    print('====')",
#   '_i20': "for el in gc.get_referrers(emp2):\n    print(el)\n    print('---')\n    ",
#   'el': {...},
#   '_i21': 'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#   '_i22': 'print(sys.getrefcount(emp2))\n# print(gc.get_referrers(emp2))',
#   '_i23': "for el in gc.get_referrers(emp2):\n    for key, item in el.items()\n    print(key)\n    print('----')\n    print(item)\n    print('---')\n    ",
#   '_i24': "for el in gc.get_referrers(emp2):\n    for key, item in el.items():\n    print(key)\n    print('----')\n    print(item)\n    print('---')\n    print('====')\n    ",
#   '_i25': "for el in gc.get_referrers(emp2):\n    for key, item in el.items():\n        print(key)\n        print('----')\n        print(item)\n        print('---')\n        print('====')\n    ",
#   'key': '__name__',
#   'item': '__main__',
#   '_i26': 'print(gc.get_referrers())',
#   '_i27': 'print(sys.getrefcount(emp2))\nprint(gc.get_referrers(emp2))',
#   '_i28': 'print(sys.getrefcount(emp2))\nprint(len(gc.get_referrers(emp2)))',
#   '_i29': 'gc.get_referrers(emp2)'}]

# %%
print(sys.getrefcount(emp1))
# Out:
# 4

# %%
del emp2 ## del statement removes a variable and its reference (not the object itself). 
# This is often useful when working in Jupyter notebooks because all cell variables use the global scope.
# Out:
# Мария уничтожен

# %%
print(sys.getrefcount(emp2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-de4b854674ef> in <module>
# ----> 1 print(sys.getrefcount(emp2))
#
# NameError: name 'emp2' is not defined

# %%
del emp1 #After Python executes the del statement,
# our objects are no longer accessible from Python code. However, such objects can still be sitting in the memory

# %%
print(sys.getrefcount(emp1)) # переменную мы удалили, но объект остался. на это указывает то, что метод __del__ не был вызван выше
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-4782a375ae71> in <module>
# ----> 1 print(sys.getrefcount(emp1))
#
# NameError: name 'emp1' is not defined

# %%
class Employee:
    """Базовый класс для всех сотрудников"""
    instances = []

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        Employee.instances.append(self)

    @classmethod
    def display_count(cls):
        print('Всего сотрудников: %d' % len(Employee.instances))

    def display_employee(self):
        print('Имя: {}. Зарплата: {}'.format(self.name, self.salary))

    def delete_employee(self):
        Employee.instances.remove(self)
        del self

    def __del__(self): #del self does almost nothing -- it only deletes the local variable that is named self.
        # But as that isn't the last reference to the instance (whatever called this method also still has a reference, at least) the object will continue to exist.
        # !!! Calling __del__ manually also achieves nothing except for running that method; it doesn't delete anything.
        # print(self)
        # class_name = self.__class__.__name__
        print('{} уничтожен'.format(self.name))
